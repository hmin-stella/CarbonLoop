# %%
ls
# Out:
# 00-model-conv1d-1level/            05-mapper-conv1d+oc-3level/
# 01-model-conv1d-2level/            06-mapper-convlayer-eyeriss/
# 02-model-conv1d+oc-2level/         elee_timeloop_exercise.ipynb
# 03-model-conv1d+oc-3level/         run_example.py*
# 04-model-conv1d+oc-3levelspatial/

# %%
# !python3 run_example.py 00
# 00-model-conv1d-1level
# Out:
# ...
# Calling exercise 00. Code is:
# def run_exercise_00(out_dir: str = "output"):
#     start_dir = os.path.join(THIS_SCRIPT_DIR, "00-model-conv1d-1level")
#     spec = tl.Specification.from_yaml_files(
#         os.path.join(start_dir, "arch/*.yaml"),
#         os.path.join(start_dir, "map/*.yaml"),
#         os.path.join(start_dir, "prob/*.yaml"),
#     )
#     tl.call_model(spec, output_dir=os.path.join(start_dir, f"{out_dir}"))
#
# WARNING:root:Factors given as string "R=3 P=16". Trying to turn into a list.
# WARNING:root:Permutation given as string "RP". Trying to turn into a list.
# input file: /home/workspace/tutorial_exercises/01_accelergy_timeloop_2020_ispass/timeloop/00-model-conv1d-1level/output/parsed-processed-input.yaml
# execute:/usr/local/bin/accelergy /home/workspace/tutorial_exercises/01_accelergy_timeloop_2020_ispass/timeloop/00-model-conv1d-1level/output/parsed-processed-input.yaml --oprefix timeloop-model. -o ./ > timeloop-model.accelergy.log 2>&1
# ...

# %%
# !python3 run_example.py 06
# Out:
# ...
# Calling exercise 06. Code is:
# def run_exercise_06(out_dir: str = "output"):
#     start_dir = os.path.join(THIS_SCRIPT_DIR, "06-mapper-convlayer-eyeriss")
#     spec = tl.Specification.from_yaml_files(
#         os.path.join(start_dir, "arch/*.yaml"),
#         os.path.join(start_dir, "arch/components/*.yaml"),
#         os.path.join(start_dir, "prob/*.yaml"),
#         os.path.join(start_dir, "mapper/*.yaml"),
#     )
#     tl.call_mapper(spec, output_dir=os.path.join(start_dir, f"{out_dir}"))
#
# input file: /home/workspace/tutorial_exercises/01_accelergy_timeloop_2020_ispass/timeloop/06-mapper-convlayer-eyeriss/output/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# ...
